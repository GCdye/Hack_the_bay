# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./data/Water_CLEAN.csv', parse_dates = ['Date_Time'], index_col = 'Date_Time')
df.drop(columns = 'Unnamed: 0', inplace = True)

# %%
df_potomac = df.loc[df.HUCNAME_.str.contains('Potomac')]

# %%
df_potomac.head()
# Out:
#                     Agency  Cruise Database         HUC12  Latitude Layer  \
# Date_Time
# 2009-10-06 12:45:00  MDDNR  BAY514      CBP  2.070002e+10  39.38935    S
# 2009-10-06 12:45:00  MDDNR  BAY514      CBP  2.070002e+10  39.38935    S
# 2009-10-06 12:45:00  MDDNR  BAY514      CBP  2.070002e+10  39.38935    S
# 2009-10-06 12:45:00  MDDNR  BAY514      CBP  2.070002e+10  39.38935    S
# 2009-10-06 12:45:00  MDDNR  BAY514      CBP  2.070002e+10  39.38935    S
#
#                      Longitude  MeasureValue Method Parameter  ...  \
# Date_Time                                                      ...
# 2009-10-06 12:45:00  -79.17936        10.000   F01         DO  ...
# 2009-10-06 12:45:00  -79.17936         1.222   L01       NH4F  ...
# 2009-10-06 12:45:00  -79.17936         2.463   D01       NO3F  ...
# 2009-10-06 12:45:00  -79.17936         7.600   F01         PH  ...
# 2009-10-06 12:45:00  -79.17936         0.006   L01       PO4F  ...
#
#                       TideStage TierLevel  Unit                       Point  \
# Date_Time
# 2009-10-06 12:45:00    Ebb Tide        T3  MG/L  POINT (-79.17936 39.38935)
# 2009-10-06 12:45:00  Flood Tide        T3  MG/L  POINT (-79.17936 39.38935)
# 2009-10-06 12:45:00  Flood Tide        T3  MG/L  POINT (-79.17936 39.38935)
# 2009-10-06 12:45:00    Ebb Tide        T3    SU  POINT (-79.17936 39.38935)
# 2009-10-06 12:45:00    Ebb Tide        T3  MG/L  POINT (-79.17936 39.38935)
#
#                           HUC12_                                 HUCNAME_  \
# Date_Time
# 2009-10-06 12:45:00  20700020205  Lostland Run-North Branch Potomac River
# 2009-10-06 12:45:00  20700020205  Lostland Run-North Branch Potomac River
# 2009-10-06 12:45:00  20700020205  Lostland Run-North Branch Potomac River
# 2009-10-06 12:45:00  20700020205  Lostland Run-North Branch Potomac River
# 2009-10-06 12:45:00  20700020205  Lostland Run-North Branch Potomac River
#
#                      FIPS_         COUNTY_ STATE_ TotalDepth
# Date_Time
# 2009-10-06 12:45:00  24023  Garrett County     MD        0.0
# 2009-10-06 12:45:00  24023  Garrett County     MD        0.0
# 2009-10-06 12:45:00  24023  Garrett County     MD        0.0
# 2009-10-06 12:45:00  24023  Garrett County     MD        0.0
# 2009-10-06 12:45:00  24023  Garrett County     MD        0.0
#
# [5 rows x 29 columns]

# %%
df_potomac.drop(columns = 'ParameterName_CBP', inplace = True)

# %%
def make_parameters(df):
    dums = pd.get_dummies(df['Parameter'], prefix = 'Parameter')
    df = pd.concat([df,dums], axis = 1).drop(columns = 'Parameter')
    
    param_cols = []
    for col in df:
        if col.startswith('Parameter'):
            param_cols.append(col)

    for col in param_cols:
        df[f'{col}'].where(df[f'{col}'] == 0, 
                           df['MeasureValue'], inplace = True)
    df.drop(columns = 'MeasureValue', inplace = True)
    df = df.groupby(by = [df.index, 'SampleId','SampleDepth']).max()
    df.reset_index(level = ['SampleId', 'SampleDepth'], inplace = True)
    return df

# %%
df = make_parameters(df_potomac)

# %%
df.columns
# Out:
# Index(['SampleId', 'SampleDepth', 'Agency', 'Cruise', 'Database', 'HUC12',
#        'Latitude', 'Layer', 'Longitude', 'Method', 'Program', 'Project',
#        'SampleReplicateType', 'SampleType', 'Source', 'Station', 'TideStage',
#        'TierLevel', 'Unit', 'Point', 'HUC12_', 'HUCNAME_', 'FIPS_', 'COUNTY_',
#        'STATE_', 'TotalDepth', 'Parameter_CHLA', 'Parameter_DO',
#        'Parameter_NH4F', 'Parameter_NO3F', 'Parameter_PH', 'Parameter_PO4F',
#        'Parameter_SALINITY', 'Parameter_SECCHI', 'Parameter_TALK',
#        'Parameter_TDS', 'Parameter_TKNW', 'Parameter_TN', 'Parameter_TP',
#        'Parameter_TSS', 'Parameter_TURB_NTU', 'Parameter_WTEMP'],
#       dtype='object')

# %%
df.head()
# Out:
#                      SampleId  SampleDepth Agency  Cruise Database  \
# Date_Time
# 2005-07-11 08:30:00   29047.0          0.5  MDDNR  BAY422      CBP
# 2005-07-11 08:30:00   29047.0          1.0  MDDNR  BAY422      CBP
# 2005-07-11 08:30:00   29047.0          2.0  MDDNR  BAY422      CBP
# 2005-07-11 08:30:00   29047.0          3.0  MDDNR  BAY422      CBP
# 2005-07-11 08:30:00   29047.0          4.0  MDDNR  BAY422      CBP
#
#                             HUC12  Latitude Layer  Longitude Method  ...  \
# Date_Time                                                            ...
# 2005-07-11 08:30:00  2.070011e+10   38.3626    S   -76.99063   L01   ...
# 2005-07-11 08:30:00  2.070011e+10   38.3626    M   -76.99063   F01   ...
# 2005-07-11 08:30:00  2.070011e+10   38.3626    AP  -76.99063   L01   ...
# 2005-07-11 08:30:00  2.070011e+10   38.3626    M   -76.99063   F01   ...
# 2005-07-11 08:30:00  2.070011e+10   38.3626    M   -76.99063   F01   ...
#
#                     Parameter_SALINITY Parameter_SECCHI Parameter_TALK  \
# Date_Time
# 2005-07-11 08:30:00               4.28              0.5           58.0
# 2005-07-11 08:30:00               4.31              0.0            0.0
# 2005-07-11 08:30:00               4.76              0.0           58.0
# 2005-07-11 08:30:00               5.04              0.0            0.0
# 2005-07-11 08:30:00               5.88              0.0            0.0
#
#                     Parameter_TDS Parameter_TKNW Parameter_TN Parameter_TP  \
# Date_Time
# 2005-07-11 08:30:00           0.0            0.0        0.990       0.0729
# 2005-07-11 08:30:00           0.0            0.0        0.000       0.0000
# 2005-07-11 08:30:00           0.0            0.0        1.341       0.0741
# 2005-07-11 08:30:00           0.0            0.0        0.000       0.0000
# 2005-07-11 08:30:00           0.0            0.0        0.000       0.0000
#
#                     Parameter_TSS Parameter_TURB_NTU Parameter_WTEMP
# Date_Time
# 2005-07-11 08:30:00           7.9                8.0            27.7
# 2005-07-11 08:30:00           0.0                0.0            27.6
# 2005-07-11 08:30:00           8.0                7.6            27.5
# 2005-07-11 08:30:00           0.0                0.0            27.2
# 2005-07-11 08:30:00           0.0                0.0            27.1
#
# [5 rows x 42 columns]

# %%
df.to_csv('./data/WQ_FINAL_with_Parameters.csv', index=False)
